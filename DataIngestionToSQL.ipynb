# %% [markdown]
# <a href="https://colab.research.google.com/github/VictoriaUsman/Big-Data/blob/main/DataIngestionToSQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read CSV
order = pd.read_csv("/content/olist_order_payments_dataset.csv")

# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.5.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.5 kB)
# Downloading mysql_connector_python-9.5.0-cp312-cp312-manylinux_2_28_x86_64.whl (34.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 62.8 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.5.0

# %%
order.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order.shape
# Out:
# (103886, 5)

# %%
# Validating the connection to mysql DB

# %%
import mysql.connector
from mysql.connector import Error

hostname = 'iuk338.h.filess.io'
database = 'Olist Project_villagejar'
port = 3307                 # ✅ must be int
username = 'Olist Project_villagejar'
password = '6eeed5ee7f123045a202e9d7e7d64666dd34c99c'

connection = None
cursor = None

try:
    connection = mysql.connector.connect(
        host=hostname,
        user=username,
        password=password,   # ✅ use password (not passwd)
        database=database,
        port=port            # ✅ include port
    )

    if connection.is_connected():
        db_info = connection.get_server_info()
        print("Connected to MySQL Server version:", db_info)

        cursor = connection.cursor()
        cursor.execute("SELECT DATABASE();")
        record = cursor.fetchone()
        print("You're connected to database:", record)

except Error as e:
    print(f"Error while connecting to MySQL:, {e}")

finally:
    if cursor is not None:
        cursor.close()

    if connection is not None and connection.is_connected():
        connection.close()
        print("MySQL connection is closed")
# Out:
# /tmp/ipython-input-3069070794.py:23: DeprecationWarning: Call to deprecated function get_server_info. Reason:
#     The property counterpart 'server_info' should be used instead.
#
#   db_info = connection.get_server_info()
# Connected to MySQL Server version: 8.0.36-28
# You're connected to database: ('Olist Project_villagejar',)
# MySQL connection is closed

# %%
hostname = 'iuk338.h.filess.io'
database = 'Olist Project_villagejar'
port = 3307                 # ✅ must be int
username = 'Olist Project_villagejar'
password = '6eeed5ee7f123045a202e9d7e7d64666dd34c99c'

connection = None
cursor = None

connection = mysql.connector.connect(
    host=hostname,
    user=username,
    password=password,   # ✅ use password (not passwd)
    database=database,
    port=port            # ✅ include port
)

# %%
#Create Table Query
cursor = connection.cursor()

create_table_query = '''
  DROP TABLE olist_order_payments_dataset;
  CREATE TABLE IF NOT EXISTS olist_order_payments_dataset (
    order_id VARCHAR(50),
    payment_sequential INT,
    payment_type VARCHAR(255),
    payment_installments INT,
    payment_value FLOAT)'''
cursor.execute(create_table_query)
connection.commit()
print("Table created successfully")
# Out:
# Table created successfully

# %%
#loading the order_payment dataset to filess.io
print('Order Payment set is being loaded...')
# Out:
# Order Payment set is being loaded...

# %%
#Inserting data in batches of 1000 records
batch_size = 500
total_records = len(order)
table_name = 'olist_order_payments_dataset'
try:
  print('Starting loading process...')
  for i in range(0, total_records, batch_size):
    end_index = i + batch_size
    batch_df = order.iloc[i:end_index]

    # Converting batch records into a list of tuples for MySQL insertion
    batch_records = [
        tuple(row) for row in batch_df.itertuples(index=False, name=None)


    ]

    #Prepare the insert query
    insert_query = f"INSERT INTO olist_order_payments_dataset (order_id, payment_sequential, payment_type, payment_installments, payment_value) VALUES (%s, %s, %s, %s, %s)"

    #Executing the insertion query
    cursor = connection.cursor()
    cursor.executemany(insert_query, batch_records)
    connection.commit()

    print(f'Inserted records {i + 1} to {min(end_index, total_records)}')
  print(f'All {total_records} was inserted into {table_name}')
except Error as e:
  print(f'Error while connecting to MySQL: {e}')

finally:
  if cursor is not None:
    cursor.close()

  if connection is not None and connection.is_connected():
    connection.close()
    print("MySQL connection is closed")
#
# Out:
# Starting loading process...
# Inserted records 1 to 500
# Inserted records 501 to 1000
# Inserted records 1001 to 1500
# Inserted records 1501 to 2000
# Inserted records 2001 to 2500
# Inserted records 2501 to 3000
# Inserted records 3001 to 3500
# Inserted records 3501 to 4000
# Inserted records 4001 to 4500
# Inserted records 4501 to 5000
# Inserted records 5001 to 5500
# Inserted records 5501 to 6000
# Inserted records 6001 to 6500
# Inserted records 6501 to 7000
# Inserted records 7001 to 7500
# Inserted records 7501 to 8000
# Inserted records 8001 to 8500
# Inserted records 8501 to 9000
# Inserted records 9001 to 9500
# Inserted records 9501 to 10000
# Inserted records 10001 to 10500
# Inserted records 10501 to 11000
# Inserted records 11001 to 11500
# Inserted records 11501 to 12000
# Inserted records 12001 to 12500
# Inserted records 12501 to 13000
# Inserted records 13001 to 13500
# Inserted records 13501 to 14000
# Inserted records 14001 to 14500
# Inserted records 14501 to 15000
# Inserted records 15001 to 15500
# Inserted records 15501 to 16000
# Inserted records 16001 to 16500
# Inserted records 16501 to 17000
# Inserted records 17001 to 17500
# Inserted records 17501 to 18000
# Inserted records 18001 to 18500
# Inserted records 18501 to 19000
# Inserted records 19001 to 19500
# Inserted records 19501 to 20000
# Inserted records 20001 to 20500
# Inserted records 20501 to 21000
# Inserted records 21001 to 21500
# Inserted records 21501 to 22000
# Inserted records 22001 to 22500
# Inserted records 22501 to 23000
# Inserted records 23001 to 23500
# Inserted records 23501 to 24000
# Inserted records 24001 to 24500
# Inserted records 24501 to 25000
# Inserted records 25001 to 25500
# Inserted records 25501 to 26000
# Inserted records 26001 to 26500
# Inserted records 26501 to 27000
# Inserted records 27001 to 27500
# Inserted records 27501 to 28000
# Inserted records 28001 to 28500
# Inserted records 28501 to 29000
# Inserted records 29001 to 29500
# Inserted records 29501 to 30000
# Inserted records 30001 to 30500
# Inserted records 30501 to 31000
# Inserted records 31001 to 31500
# Inserted records 31501 to 32000
# Inserted records 32001 to 32500
# Inserted records 32501 to 33000
# Inserted records 33001 to 33500
# Inserted records 33501 to 34000
# Inserted records 34001 to 34500
# Inserted records 34501 to 35000
# Inserted records 35001 to 35500
# Inserted records 35501 to 36000
# Inserted records 36001 to 36500
# Inserted records 36501 to 37000
# Inserted records 37001 to 37500
# Inserted records 37501 to 38000
# Inserted records 38001 to 38500
# Inserted records 38501 to 39000
# Inserted records 39001 to 39500
# Inserted records 39501 to 40000
# Inserted records 40001 to 40500
# Inserted records 40501 to 41000
# Inserted records 41001 to 41500
# Inserted records 41501 to 42000
# Inserted records 42001 to 42500
# Inserted records 42501 to 43000
# Inserted records 43001 to 43500
# Inserted records 43501 to 44000
# Inserted records 44001 to 44500
# Inserted records 44501 to 45000
# Inserted records 45001 to 45500
# Inserted records 45501 to 46000
# Inserted records 46001 to 46500
# Inserted records 46501 to 47000
# Inserted records 47001 to 47500
# Inserted records 47501 to 48000
# Inserted records 48001 to 48500
# Inserted records 48501 to 49000
# Inserted records 49001 to 49500
# Inserted records 49501 to 50000
# Inserted records 50001 to 50500
# Inserted records 50501 to 51000
# Inserted records 51001 to 51500
# Inserted records 51501 to 52000
# Inserted records 52001 to 52500
# Inserted records 52501 to 53000
# Inserted records 53001 to 53500
# Inserted records 53501 to 54000
# Inserted records 54001 to 54500
# Inserted records 54501 to 55000
# Inserted records 55001 to 55500
# Inserted records 55501 to 56000
# Inserted records 56001 to 56500
# Inserted records 56501 to 57000
# Inserted records 57001 to 57500
# Inserted records 57501 to 58000
# Inserted records 58001 to 58500
# Inserted records 58501 to 59000
# Inserted records 59001 to 59500
# Inserted records 59501 to 60000
# Inserted records 60001 to 60500
# Inserted records 60501 to 61000
# Inserted records 61001 to 61500
# Inserted records 61501 to 62000
# Inserted records 62001 to 62500
# Inserted records 62501 to 63000
# Inserted records 63001 to 63500
# Inserted records 63501 to 64000
# Inserted records 64001 to 64500
# Inserted records 64501 to 65000
# Inserted records 65001 to 65500
# Inserted records 65501 to 66000
# Inserted records 66001 to 66500
# Inserted records 66501 to 67000
# Inserted records 67001 to 67500
# Inserted records 67501 to 68000
# Inserted records 68001 to 68500
# Inserted records 68501 to 69000
# Inserted records 69001 to 69500
# Inserted records 69501 to 70000
# Inserted records 70001 to 70500
# Inserted records 70501 to 71000
# Inserted records 71001 to 71500
# Inserted records 71501 to 72000
# Inserted records 72001 to 72500
# Inserted records 72501 to 73000
# Inserted records 73001 to 73500
# Inserted records 73501 to 74000
# Inserted records 74001 to 74500
# Inserted records 74501 to 75000
# Inserted records 75001 to 75500
# Inserted records 75501 to 76000
# Inserted records 76001 to 76500
# Inserted records 76501 to 77000
# Inserted records 77001 to 77500
# Inserted records 77501 to 78000
# Inserted records 78001 to 78500
# Inserted records 78501 to 79000
# Inserted records 79001 to 79500
# Inserted records 79501 to 80000
# Inserted records 80001 to 80500
# Inserted records 80501 to 81000
# Inserted records 81001 to 81500
# Inserted records 81501 to 82000
# Inserted records 82001 to 82500
# Inserted records 82501 to 83000
# Inserted records 83001 to 83500
# Inserted records 83501 to 84000
# Inserted records 84001 to 84500
# Inserted records 84501 to 85000
# Inserted records 85001 to 85500
# Inserted records 85501 to 86000
# Inserted records 86001 to 86500
# Inserted records 86501 to 87000
# Inserted records 87001 to 87500
# Inserted records 87501 to 88000
# Inserted records 88001 to 88500
# Inserted records 88501 to 89000
# Inserted records 89001 to 89500
# Inserted records 89501 to 90000
# Inserted records 90001 to 90500
# Inserted records 90501 to 91000
# Inserted records 91001 to 91500
# Inserted records 91501 to 92000
# Inserted records 92001 to 92500
# Inserted records 92501 to 93000
# Inserted records 93001 to 93500
# Inserted records 93501 to 94000
# Inserted records 94001 to 94500
# Inserted records 94501 to 95000
# Inserted records 95001 to 95500
# Inserted records 95501 to 96000
# Inserted records 96001 to 96500
# Inserted records 96501 to 97000
# Inserted records 97001 to 97500
# Inserted records 97501 to 98000
# Inserted records 98001 to 98500
# Inserted records 98501 to 99000
# Inserted records 99001 to 99500
# Inserted records 99501 to 100000
# Inserted records 100001 to 100500
# Inserted records 100501 to 101000
# Inserted records 101001 to 101500
# Inserted records 101501 to 102000
# Inserted records 102001 to 102500
# Inserted records 102501 to 103000
# Inserted records 103001 to 103500
# Inserted records 103501 to 103886
# All 103886 was inserted into olist_order_payments_dataset
# MySQL connection is closed
