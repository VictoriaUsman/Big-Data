# %%
from pyspark.sql import *

# %%
from pyspark.sql.functions import *

# %%
path = '/data/'

# %%
geolocation = spark.read.csv(path+'olist_geolocation_dataset.csv',header=True,inferSchema = True)
order_items = spark.read.csv(path+'olist_order_items_dataset.csv',header=True,inferSchema = True)
payments = spark.read.csv(path+'olist_order_payments_dataset.csv',header=True,inferSchema = True)
reviews = spark.read.csv(path+'olist_order_reviews_dataset.csv',header=True,inferSchema = True)
orders = spark.read.csv(path+'olist_orders_dataset.csv',header=True,inferSchema = True)
products = spark.read.csv(path+'olist_products_dataset.csv',header=True,inferSchema = True)
seller = spark.read.csv(path+'olist_sellers_dataset.csv',header=True,inferSchema = True)
customer = spark.read.csv(path+'olist_customers_dataset.csv',header=True,inferSchema = True)

# %%
customer.show()
# Out:
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|                   14409|              franca|            SP|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|                    9790|sao bernardo do c...|            SP|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|                    1151|           sao paulo|            SP|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|                    8775|     mogi das cruzes|            SP|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|                   13056|            campinas|            SP|
# |879864dab9bc30475...|4c93744516667ad3b...|                   89254|      jaragua do sul|            SC|
# |fd826e7cf63160e53...|addec96d2e059c80c...|                    4534|           sao paulo|            SP|
# |5e274e7a0c3809e14...|57b2a98a409812fe9...|                   35182|             timoteo|            MG|
# |5adf08e34b2e99398...|1175e95fb47ddff9d...|                   81560|            curitiba|            PR|
# |4b7139f34592b3a31...|9afe194fb833f79e3...|                   30575|      belo horizonte|            MG|
# |9fb35e4ed6f0a14a4...|2a7745e1ed516b289...|                   39400|       montes claros|            MG|
# |5aa9e4fdd4dfd2095...|2a46fb94aef5cbeeb...|                   20231|      rio de janeiro|            RJ|
# |b2d1536598b73a9ab...|918dc87cd72cd9f6e...|                   18682|    lencois paulista|            SP|
# |eabebad39a88bb6f5...|295c05e81917928d7...|                    5704|           sao paulo|            SP|
# |1f1c7bf1c9b041b29...|3151a81801c838636...|                   95110|       caxias do sul|            RS|
# |206f3129c0e4d7d0b...|21f748a16f4e1688a...|                   13412|          piracicaba|            SP|
# |a7c125a0a07b75146...|5c2991dbd08bbf3cf...|                   22750|      rio de janeiro|            RJ|
# |c5c61596a3b6bd0ce...|b6e99561fe6f34a55...|                    7124|           guarulhos|            SP|
# |9b8ce803689b3562d...|7f3a72e8f988c6e73...|                    5416|           sao paulo|            SP|
# |49d0ea0986edde72d...|3e6fd6b2f0d499456...|                   68485|              pacaja|            PA|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# only showing top 20 rows

# %% [markdown]
# **Checking for Null Values

# %%
def null_values(df,df_name):
    print(f'Looking at {df_name}')
    df.select([count(when(col(c).isNull(), 1)).alias(c)for c in df.columns]).show()

# %%
null_values(geolocation,'geolocation')
# Out:
# Looking at geolocation
# [Stage 17:=============================>                            (1 + 1) / 2]
# +---------------------------+---------------+---------------+----------------+-----------------+
# |geolocation_zip_code_prefix|geolocation_lat|geolocation_lng|geolocation_city|geolocation_state|
# +---------------------------+---------------+---------------+----------------+-----------------+
# |                          0|              0|              0|               0|                0|
# +---------------------------+---------------+---------------+----------------+-----------------+

# %%
null_values(order_items,'order_items')
# Out:
# Looking at order_items
# [Stage 20:=============================>                            (1 + 1) / 2]
# +--------+-------------+----------+---------+-------------------+-----+-------------+
# |order_id|order_item_id|product_id|seller_id|shipping_limit_date|price|freight_value|
# +--------+-------------+----------+---------+-------------------+-----+-------------+
# |       0|            0|         0|        0|                  0|    0|            0|
# +--------+-------------+----------+---------+-------------------+-----+-------------+

# %%
null_values(payments,'payments')
# Out:
# Looking at payments
# [Stage 23:=============================>                            (1 + 1) / 2]
# +--------+------------------+------------+--------------------+-------------+
# |order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------+------------------+------------+--------------------+-------------+
# |       0|                 0|           0|                   0|            0|
# +--------+------------------+------------+--------------------+-------------+

# %%
null_values(reviews,'reviews')
# Out:
# Looking at reviews
# [Stage 26:=============================>                            (1 + 1) / 2]
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+
# |review_id|order_id|review_score|review_comment_title|review_comment_message|review_creation_date|review_answer_timestamp|
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+
# |        1|    2236|        2380|               92157|                 63079|                8764|                   8785|
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+

# %%
null_values(orders,'orders')
# Out:
# Looking at orders
# [Stage 29:=============================>                            (1 + 1) / 2]
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+
# |order_id|customer_id|order_status|order_purchase_timestamp|order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+
# |       0|          0|           0|                       0|              160|                        1783|                         2965|                            0|
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+

# %%
null_values(products,'products')
# Out:
# Looking at products
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |product_id|product_category_name|product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |         0|                  610|                610|                       610|               610|               2|                2|                2|               2|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+

# %%
null_values(seller,'seller')
# Out:
# Looking at seller
# +---------+----------------------+-----------+------------+
# |seller_id|seller_zip_code_prefix|seller_city|seller_state|
# +---------+----------------------+-----------+------------+
# |        0|                     0|          0|           0|
# +---------+----------------------+-----------+------------+

# %%
null_values(customer,'customer')
# Out:
# Looking at customer
# +-----------+------------------+------------------------+-------------+--------------+
# |customer_id|customer_unique_id|customer_zip_code_prefix|customer_city|customer_state|
# +-----------+------------------+------------------------+-------------+--------------+
# |          0|                 0|                       0|            0|             0|
# +-----------+------------------+------------------------+-------------+--------------+

# %% [markdown]
# **Handling Missing Values

# %%
cleaned_orders = orders.na.drop(
    subset=['order_id', 'customer_id', 'order_status']
)

# %%
cleaned_orders.show(10)
# Out:
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|     2017-10-02 10:56:33|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|     2018-07-24 20:41:37|2018-07-26 03:24:27|         2018-07-26 14:31:00|          2018-08-07 15:27:45|          2018-08-13 00:00:00|
# |47770eb9100c2d0c4...|41ce2a54c0b03bf34...|   delivered|     2018-08-08 08:38:49|2018-08-08 08:55:23|         2018-08-08 13:50:00|          2018-08-17 18:06:29|          2018-09-04 00:00:00|
# |949d5b44dbf5de918...|f88197465ea7920ad...|   delivered|     2017-11-18 19:28:06|2017-11-18 19:45:59|         2017-11-22 13:39:59|          2017-12-02 00:28:42|          2017-12-15 00:00:00|
# |ad21c59c0840e6cb8...|8ab97904e6daea886...|   delivered|     2018-02-13 21:18:39|2018-02-13 22:20:29|         2018-02-14 19:46:34|          2018-02-16 18:17:02|          2018-02-26 00:00:00|
# |a4591c265e18cb1dc...|503740e9ca751ccdd...|   delivered|     2017-07-09 21:57:05|2017-07-09 22:10:13|         2017-07-11 14:58:04|          2017-07-26 10:57:55|          2017-08-01 00:00:00|
# |136cce7faa42fdb2c...|ed0271e0b7da060a3...|    invoiced|     2017-04-11 12:22:08|2017-04-13 13:25:17|                        NULL|                         NULL|          2017-05-09 00:00:00|
# |6514b8ad8028c9f2c...|9bdf08b4b3b52b552...|   delivered|     2017-05-16 13:10:30|2017-05-16 13:22:11|         2017-05-22 10:07:46|          2017-05-26 12:55:51|          2017-06-07 00:00:00|
# |76c6e866289321a7c...|f54a9f0e6b351c431...|   delivered|     2017-01-23 18:29:09|2017-01-25 02:50:47|         2017-01-26 14:16:31|          2017-02-02 14:08:10|          2017-03-06 00:00:00|
# |e69bfb5eb88e0ed6a...|31ad1d1b63eb99624...|   delivered|     2017-07-29 11:55:02|2017-07-29 12:05:32|         2017-08-10 19:45:24|          2017-08-16 17:14:30|          2017-08-23 00:00:00|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# only showing top 10 rows

# %% [markdown]
# **Filling null values

# %%
cleaned_orders = orders.fillna({'order_delivered_customer_date':'9999-12-31'})

# %%
cleaned_orders.show(10)
# Out:
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|     2017-10-02 10:56:33|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|     2018-07-24 20:41:37|2018-07-26 03:24:27|         2018-07-26 14:31:00|          2018-08-07 15:27:45|          2018-08-13 00:00:00|
# |47770eb9100c2d0c4...|41ce2a54c0b03bf34...|   delivered|     2018-08-08 08:38:49|2018-08-08 08:55:23|         2018-08-08 13:50:00|          2018-08-17 18:06:29|          2018-09-04 00:00:00|
# |949d5b44dbf5de918...|f88197465ea7920ad...|   delivered|     2017-11-18 19:28:06|2017-11-18 19:45:59|         2017-11-22 13:39:59|          2017-12-02 00:28:42|          2017-12-15 00:00:00|
# |ad21c59c0840e6cb8...|8ab97904e6daea886...|   delivered|     2018-02-13 21:18:39|2018-02-13 22:20:29|         2018-02-14 19:46:34|          2018-02-16 18:17:02|          2018-02-26 00:00:00|
# |a4591c265e18cb1dc...|503740e9ca751ccdd...|   delivered|     2017-07-09 21:57:05|2017-07-09 22:10:13|         2017-07-11 14:58:04|          2017-07-26 10:57:55|          2017-08-01 00:00:00|
# |136cce7faa42fdb2c...|ed0271e0b7da060a3...|    invoiced|     2017-04-11 12:22:08|2017-04-13 13:25:17|                        NULL|          9999-12-31 00:00:00|          2017-05-09 00:00:00|
# |6514b8ad8028c9f2c...|9bdf08b4b3b52b552...|   delivered|     2017-05-16 13:10:30|2017-05-16 13:22:11|         2017-05-22 10:07:46|          2017-05-26 12:55:51|          2017-06-07 00:00:00|
# |76c6e866289321a7c...|f54a9f0e6b351c431...|   delivered|     2017-01-23 18:29:09|2017-01-25 02:50:47|         2017-01-26 14:16:31|          2017-02-02 14:08:10|          2017-03-06 00:00:00|
# |e69bfb5eb88e0ed6a...|31ad1d1b63eb99624...|   delivered|     2017-07-29 11:55:02|2017-07-29 12:05:32|         2017-08-10 19:45:24|          2017-08-16 17:14:30|          2017-08-23 00:00:00|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# only showing top 10 rows

# %% [markdown]
# **Impute null values

# %%
payments.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)

# %%
payments.filter(col('payment_value').isNull()).count()
# Out:
# 0

# %%
payments_w_null = payments.withColumn('payment_value', when(col('payment_value')!=99.33,col('payment_value')).otherwise(lit(None)))

# %%
payments_w_null.show()
# Out:
# +--------------------+------------------+------------+--------------------+-------------+
# |            order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------+------------------+------------+--------------------+-------------+
# |b81ef226f3fe1789b...|                 1| credit_card|                   8|         NULL|
# |a9810da82917af2d9...|                 1| credit_card|                   1|        24.39|
# |25e8ea4e93396b6fa...|                 1| credit_card|                   1|        65.71|
# |ba78997921bbcdc13...|                 1| credit_card|                   8|       107.78|
# |42fdf880ba16b47b5...|                 1| credit_card|                   2|       128.45|
# |298fcdf1f73eb413e...|                 1| credit_card|                   2|        96.12|
# |771ee386b001f0620...|                 1| credit_card|                   1|        81.16|
# |3d7239c394a212faa...|                 1| credit_card|                   3|        51.84|
# |1f78449c87a54faf9...|                 1| credit_card|                   6|       341.09|
# |0573b5e23cbd79800...|                 1|      boleto|                   1|        51.95|
# |d88e0d5fa41661ce0...|                 1| credit_card|                   8|       188.73|
# |2480f727e869fdeb3...|                 1| credit_card|                   1|        141.9|
# |616105c9352a9668c...|                 1| credit_card|                   1|        75.78|
# |cf95215a722f3ebf2...|                 1| credit_card|                   5|       102.66|
# |769214176682788a9...|                 1| credit_card|                   4|       105.28|
# |12e5cfe0e4716b59a...|                 1| credit_card|                  10|       157.45|
# |61059985a6fc0ad64...|                 1| credit_card|                   1|       132.04|
# |79da3f5fe31ad1e45...|                 1| credit_card|                   1|        98.94|
# |8ac09207f415d55ac...|                 1| credit_card|                   4|       244.15|
# |b2349a3f20dfbeef6...|                 1| credit_card|                   3|       136.71|
# +--------------------+------------------+------------+--------------------+-------------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import Imputer

# %%
imputer = Imputer(inputCols = ['payment_value'], outputCols = ['payment_value_imputed']).setStrategy('median')

# %%
cleaned_payments = imputer.fit(payments_w_null).transform(payments_w_null)

# %%
cleaned_payments.show() ##showing close to 99.33
# Out:
# +--------------------+------------------+------------+--------------------+-------------+---------------------+
# |            order_id|payment_sequential|payment_type|payment_installments|payment_value|payment_value_imputed|
# +--------------------+------------------+------------+--------------------+-------------+---------------------+
# |b81ef226f3fe1789b...|                 1| credit_card|                   8|         NULL|                100.0|
# |a9810da82917af2d9...|                 1| credit_card|                   1|        24.39|                24.39|
# |25e8ea4e93396b6fa...|                 1| credit_card|                   1|        65.71|                65.71|
# |ba78997921bbcdc13...|                 1| credit_card|                   8|       107.78|               107.78|
# |42fdf880ba16b47b5...|                 1| credit_card|                   2|       128.45|               128.45|
# |298fcdf1f73eb413e...|                 1| credit_card|                   2|        96.12|                96.12|
# |771ee386b001f0620...|                 1| credit_card|                   1|        81.16|                81.16|
# |3d7239c394a212faa...|                 1| credit_card|                   3|        51.84|                51.84|
# |1f78449c87a54faf9...|                 1| credit_card|                   6|       341.09|               341.09|
# |0573b5e23cbd79800...|                 1|      boleto|                   1|        51.95|                51.95|
# |d88e0d5fa41661ce0...|                 1| credit_card|                   8|       188.73|               188.73|
# |2480f727e869fdeb3...|                 1| credit_card|                   1|        141.9|                141.9|
# |616105c9352a9668c...|                 1| credit_card|                   1|        75.78|                75.78|
# |cf95215a722f3ebf2...|                 1| credit_card|                   5|       102.66|               102.66|
# |769214176682788a9...|                 1| credit_card|                   4|       105.28|               105.28|
# |12e5cfe0e4716b59a...|                 1| credit_card|                  10|       157.45|               157.45|
# |61059985a6fc0ad64...|                 1| credit_card|                   1|       132.04|               132.04|
# |79da3f5fe31ad1e45...|                 1| credit_card|                   1|        98.94|                98.94|
# |8ac09207f415d55ac...|                 1| credit_card|                   4|       244.15|               244.15|
# |b2349a3f20dfbeef6...|                 1| credit_card|                   3|       136.71|               136.71|
# +--------------------+------------------+------------+--------------------+-------------+---------------------+
# only showing top 20 rows

# %%
cleaned_payments.count()
# Out:
# 103886

# %% [markdown]
# **Standardizing the Format

# %%
def print_schema(df,df_name):
    print(f'Looking at {df_name}-')
    print(df.printSchema())

# %%
print_schema(geolocation,'geolocation')
# Out:
# Looking at geolocation-
# root
#  |-- geolocation_zip_code_prefix: integer (nullable = true)
#  |-- geolocation_lat: double (nullable = true)
#  |-- geolocation_lng: double (nullable = true)
#  |-- geolocation_city: string (nullable = true)
#  |-- geolocation_state: string (nullable = true)
#
# None

# %%
print_schema(customer,'customer')
# Out:
# Looking at customer-
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#
# None

# %%
print_schema(order_items,'order_items')
# Out:
# Looking at order_items-
# root
#  |-- order_id: string (nullable = true)
#  |-- order_item_id: integer (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- shipping_limit_date: timestamp (nullable = true)
#  |-- price: double (nullable = true)
#  |-- freight_value: double (nullable = true)
#
# None

# %%
print_schema(payments,'payments')
# Out:
# Looking at payments-
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)
#
# None

# %%
print_schema(reviews,'reviews')
# Out:
# Looking at reviews-
# root
#  |-- review_id: string (nullable = true)
#  |-- order_id: string (nullable = true)
#  |-- review_score: string (nullable = true)
#  |-- review_comment_title: string (nullable = true)
#  |-- review_comment_message: string (nullable = true)
#  |-- review_creation_date: string (nullable = true)
#  |-- review_answer_timestamp: string (nullable = true)
#
# None

# %%
print_schema(orders,'orders')
# Out:
# Looking at orders-
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)
#
# None

# %%
print_schema(products,'products')
# Out:
# Looking at products-
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_lenght: integer (nullable = true)
#  |-- product_description_lenght: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)
#
# None

# %%
print_schema(seller,'seller')
# Out:
# Looking at seller-
# root
#  |-- seller_id: string (nullable = true)
#  |-- seller_zip_code_prefix: integer (nullable = true)
#  |-- seller_city: string (nullable = true)
#  |-- seller_state: string (nullable = true)
#
# None

# %%
print_schema(customer,'customer')
# Out:
# Looking at customer-
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#
# None

# %%
cleaned_orders.show(7)
# Out:
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|     2017-10-02 10:56:33|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|     2018-07-24 20:41:37|2018-07-26 03:24:27|         2018-07-26 14:31:00|          2018-08-07 15:27:45|          2018-08-13 00:00:00|
# |47770eb9100c2d0c4...|41ce2a54c0b03bf34...|   delivered|     2018-08-08 08:38:49|2018-08-08 08:55:23|         2018-08-08 13:50:00|          2018-08-17 18:06:29|          2018-09-04 00:00:00|
# |949d5b44dbf5de918...|f88197465ea7920ad...|   delivered|     2017-11-18 19:28:06|2017-11-18 19:45:59|         2017-11-22 13:39:59|          2017-12-02 00:28:42|          2017-12-15 00:00:00|
# |ad21c59c0840e6cb8...|8ab97904e6daea886...|   delivered|     2018-02-13 21:18:39|2018-02-13 22:20:29|         2018-02-14 19:46:34|          2018-02-16 18:17:02|          2018-02-26 00:00:00|
# |a4591c265e18cb1dc...|503740e9ca751ccdd...|   delivered|     2017-07-09 21:57:05|2017-07-09 22:10:13|         2017-07-11 14:58:04|          2017-07-26 10:57:55|          2017-08-01 00:00:00|
# |136cce7faa42fdb2c...|ed0271e0b7da060a3...|    invoiced|     2017-04-11 12:22:08|2017-04-13 13:25:17|                        NULL|          9999-12-31 00:00:00|          2017-05-09 00:00:00|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# only showing top 7 rows

# %%
cleaned_orders = cleaned_orders.withColumn('order_purchase_timestamp', to_date(col('order_purchase_timestamp'))) # example of changing the 1 column into date

# %%
cleaned_orders.show()
# Out:
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|              2017-10-02|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|              2018-07-24|2018-07-26 03:24:27|         2018-07-26 14:31:00|          2018-08-07 15:27:45|          2018-08-13 00:00:00|
# |47770eb9100c2d0c4...|41ce2a54c0b03bf34...|   delivered|              2018-08-08|2018-08-08 08:55:23|         2018-08-08 13:50:00|          2018-08-17 18:06:29|          2018-09-04 00:00:00|
# |949d5b44dbf5de918...|f88197465ea7920ad...|   delivered|              2017-11-18|2017-11-18 19:45:59|         2017-11-22 13:39:59|          2017-12-02 00:28:42|          2017-12-15 00:00:00|
# |ad21c59c0840e6cb8...|8ab97904e6daea886...|   delivered|              2018-02-13|2018-02-13 22:20:29|         2018-02-14 19:46:34|          2018-02-16 18:17:02|          2018-02-26 00:00:00|
# |a4591c265e18cb1dc...|503740e9ca751ccdd...|   delivered|              2017-07-09|2017-07-09 22:10:13|         2017-07-11 14:58:04|          2017-07-26 10:57:55|          2017-08-01 00:00:00|
# |136cce7faa42fdb2c...|ed0271e0b7da060a3...|    invoiced|              2017-04-11|2017-04-13 13:25:17|                        NULL|          9999-12-31 00:00:00|          2017-05-09 00:00:00|
# |6514b8ad8028c9f2c...|9bdf08b4b3b52b552...|   delivered|              2017-05-16|2017-05-16 13:22:11|         2017-05-22 10:07:46|          2017-05-26 12:55:51|          2017-06-07 00:00:00|
# |76c6e866289321a7c...|f54a9f0e6b351c431...|   delivered|              2017-01-23|2017-01-25 02:50:47|         2017-01-26 14:16:31|          2017-02-02 14:08:10|          2017-03-06 00:00:00|
# |e69bfb5eb88e0ed6a...|31ad1d1b63eb99624...|   delivered|              2017-07-29|2017-07-29 12:05:32|         2017-08-10 19:45:24|          2017-08-16 17:14:30|          2017-08-23 00:00:00|
# |e6ce16cb79ec1d90b...|494dded5b201313c6...|   delivered|              2017-05-16|2017-05-16 19:50:18|         2017-05-18 11:40:40|          2017-05-29 11:18:31|          2017-06-07 00:00:00|
# |34513ce0c4fab462a...|7711cf624183d843a...|   delivered|              2017-07-13|2017-07-13 20:10:08|         2017-07-14 18:43:29|          2017-07-19 14:04:48|          2017-08-08 00:00:00|
# |82566a660a982b15f...|d3e3b74c766bc6214...|   delivered|              2018-06-07|2018-06-09 03:13:12|         2018-06-11 13:29:00|          2018-06-19 12:05:52|          2018-07-18 00:00:00|
# |5ff96c15d0b717ac6...|19402a48fe860416a...|   delivered|              2018-07-25|2018-07-25 17:55:14|         2018-07-26 13:16:00|          2018-07-30 15:52:25|          2018-08-08 00:00:00|
# |432aaf21d85167c2c...|3df704f53d3f1d481...|   delivered|              2018-03-01|2018-03-01 15:10:47|         2018-03-02 21:09:20|          2018-03-12 23:36:26|          2018-03-21 00:00:00|
# |dcb36b511fcac050b...|3b6828a50ffe54694...|   delivered|              2018-06-07|2018-06-12 23:31:02|         2018-06-11 14:54:00|          2018-06-21 15:34:32|          2018-07-04 00:00:00|
# |403b97836b0c04a62...|738b086814c6fcc74...|   delivered|              2018-01-02|2018-01-02 19:09:04|         2018-01-03 18:19:09|          2018-01-20 01:38:59|          2018-02-06 00:00:00|
# |116f0b09343b49556...|3187789bec9909876...|   delivered|              2017-12-26|2017-12-26 23:50:22|         2017-12-28 18:33:05|          2018-01-08 22:36:36|          2018-01-29 00:00:00|
# |85ce859fd6dc634de...|059f7fc5719c7da6c...|   delivered|              2017-11-21|2017-11-21 00:14:22|         2017-11-23 21:32:26|          2017-11-27 18:28:00|          2017-12-11 00:00:00|
# |83018ec114eee8641...|7f8c8b9c2ae27bf33...|   delivered|              2017-10-26|2017-10-26 16:08:14|         2017-10-26 21:46:53|          2017-11-08 22:22:00|          2017-11-23 00:00:00|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# only showing top 20 rows

# %%
cleaned_payments = payments.withColumn('payment_type',when(col('payment_type') == 'boleto', 'Bank Transfer').when(col('payment_type') == 'credit_card', 'Credit Card')\
                                      .when(col('payment_type') == 'debit_card', 'Debit Card')\
                                      .when(col('payment_type') == 'voucher', 'Voucher')\
                                      .when(col('payment_type') == 'Null', 'Undefined'))  #Sample of standardizing values in Schema

# %%
cleaned_payments.show()
# Out:
# +--------------------+------------------+-------------+--------------------+-------------+
# |            order_id|payment_sequential| payment_type|payment_installments|payment_value|
# +--------------------+------------------+-------------+--------------------+-------------+
# |b81ef226f3fe1789b...|                 1|  Credit Card|                   8|        99.33|
# |a9810da82917af2d9...|                 1|  Credit Card|                   1|        24.39|
# |25e8ea4e93396b6fa...|                 1|  Credit Card|                   1|        65.71|
# |ba78997921bbcdc13...|                 1|  Credit Card|                   8|       107.78|
# |42fdf880ba16b47b5...|                 1|  Credit Card|                   2|       128.45|
# |298fcdf1f73eb413e...|                 1|  Credit Card|                   2|        96.12|
# |771ee386b001f0620...|                 1|  Credit Card|                   1|        81.16|
# |3d7239c394a212faa...|                 1|  Credit Card|                   3|        51.84|
# |1f78449c87a54faf9...|                 1|  Credit Card|                   6|       341.09|
# |0573b5e23cbd79800...|                 1|Bank Transfer|                   1|        51.95|
# |d88e0d5fa41661ce0...|                 1|  Credit Card|                   8|       188.73|
# |2480f727e869fdeb3...|                 1|  Credit Card|                   1|        141.9|
# |616105c9352a9668c...|                 1|  Credit Card|                   1|        75.78|
# |cf95215a722f3ebf2...|                 1|  Credit Card|                   5|       102.66|
# |769214176682788a9...|                 1|  Credit Card|                   4|       105.28|
# |12e5cfe0e4716b59a...|                 1|  Credit Card|                  10|       157.45|
# |61059985a6fc0ad64...|                 1|  Credit Card|                   1|       132.04|
# |79da3f5fe31ad1e45...|                 1|  Credit Card|                   1|        98.94|
# |8ac09207f415d55ac...|                 1|  Credit Card|                   4|       244.15|
# |b2349a3f20dfbeef6...|                 1|  Credit Card|                   3|       136.71|
# +--------------------+------------------+-------------+--------------------+-------------+
# only showing top 20 rows

# %%
cleaned_payments.groupBy('payment_type').count().show()
# Out:
# [Stage 60:=============================>                            (1 + 1) / 2]
# +-------------+-----+
# | payment_type|count|
# +-------------+-----+
# |  Credit Card|76795|
# |         NULL|    3|
# |Bank Transfer|19784|
# |   Debit Card| 1529|
# |      Voucher| 5775|
# +-------------+-----+

# %% [markdown]
# **Enforcing Schema Sample

# %%
customer.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %%
customer.show(10)
# Out:
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|                   14409|              franca|            SP|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|                    9790|sao bernardo do c...|            SP|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|                    1151|           sao paulo|            SP|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|                    8775|     mogi das cruzes|            SP|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|                   13056|            campinas|            SP|
# |879864dab9bc30475...|4c93744516667ad3b...|                   89254|      jaragua do sul|            SC|
# |fd826e7cf63160e53...|addec96d2e059c80c...|                    4534|           sao paulo|            SP|
# |5e274e7a0c3809e14...|57b2a98a409812fe9...|                   35182|             timoteo|            MG|
# |5adf08e34b2e99398...|1175e95fb47ddff9d...|                   81560|            curitiba|            PR|
# |4b7139f34592b3a31...|9afe194fb833f79e3...|                   30575|      belo horizonte|            MG|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# only showing top 10 rows

# %%
cleaned_customer = customer.withColumn('customer_zip_code_prefix',col('customer_zip_code_prefix').cast('string'))

# %%
cleaned_customer.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: string (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %% [markdown]
# **Removing Duplicates

# %%
cleaned_customer = cleaned_customer.dropDuplicates(['customer_id'])

# %%
cleaned_customer.count()
# Out:
# 99441

# %% [markdown]
# **Order with Details

# %%
detailed_orders = cleaned_orders.join(order_items,'order_id','left').join(cleaned_payments,'order_id','left')

# %%
detailed_orders.show(5)
# Out:
# [Stage 83:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+------------------+-------------+--------------------+-------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|order_item_id|          product_id|           seller_id|shipping_limit_date|price|freight_value|payment_sequential| payment_type|payment_installments|payment_value|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+------------------+-------------+--------------------+-------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|              2017-10-02|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|            1|87285b34884572647...|3504c0cb71d7fa48d...|2017-10-06 11:07:15|29.99|         8.72|                 2|      Voucher|                   1|        18.59|
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|              2017-10-02|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|            1|87285b34884572647...|3504c0cb71d7fa48d...|2017-10-06 11:07:15|29.99|         8.72|                 3|      Voucher|                   1|          2.0|
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|              2017-10-02|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|            1|87285b34884572647...|3504c0cb71d7fa48d...|2017-10-06 11:07:15|29.99|         8.72|                 1|  Credit Card|                   1|        18.12|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|              2018-07-24|2018-07-26 03:24:27|         2018-07-26 14:31:00|          2018-08-07 15:27:45|          2018-08-13 00:00:00|            1|595fac2a385ac33a8...|289cdb325fb7e7f89...|2018-07-30 03:24:27|118.7|        22.76|                 1|Bank Transfer|                   1|       141.46|
# |47770eb9100c2d0c4...|41ce2a54c0b03bf34...|   delivered|              2018-08-08|2018-08-08 08:55:23|         2018-08-08 13:50:00|          2018-08-17 18:06:29|          2018-09-04 00:00:00|            1|aa4383b373c6aca5d...|4869f7a5dfa277a7d...|2018-08-13 08:55:23|159.9|        19.22|                 1|  Credit Card|                   3|       179.12|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+------------------+-------------+--------------------+-------------+
# only showing top 5 rows

# %%
orders.show(2)
# Out:
# [Stage 79:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|     2017-10-02 10:56:33|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|     2018-07-24 20:41:37|2018-07-26 03:24:27|         2018-07-26 14:31:00|          2018-08-07 15:27:45|          2018-08-13 00:00:00|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# only showing top 2 rows

# %% [markdown]
# **Feature Engineering - Showing total payment value for one order id

# %%
orders_value = detailed_orders.groupBy('order_id').agg(sum('payment_value').alias('total')).orderBy('total', ascending=False)

# %%
orders_value.show()
# Out:
# [Stage 108:==============>                                          (1 + 3) / 4]
# +--------------------+------------------+
# |            order_id|             total|
# +--------------------+------------------+
# |03caa2c082116e1d3...|         109312.64|
# |ab14fdcfbe524636d...| 45256.00000000001|
# |1b15974a0141d54e3...|44048.000000000015|
# |2cc9089445046817a...|          36489.24|
# |e8fa22c3673b1dd17...|30185.999999999993|
# |736e1922ae60d0d6a...|          29099.52|
# |9aec4e1ae90b23c7b...|           22346.6|
# |71dab1155600756af...|21874.049999999996|
# |912343626f370ead5...|          19457.04|
# |4412d97cb2093633a...|          19174.38|
# |9f5054bd9a3c71702...|18667.000000000004|
# |428a2f660dc84138d...|          18384.75|
# |3a213fcdfe7d98be7...|          17786.88|
# |f80549a97eb203e15...|           17671.0|
# |cf4659487be50c0c3...|          17069.76|
# |be382a9e1ed251281...|16313.600000000002|
# |637617b3ffe9e2f7a...|14963.639999999998|
# |c52c7fbe316b5b9d5...|14577.569999999998|
# |f60ce04ff8060152c...|14401.000000000002|
# |73c8ab38f07dc9438...|14196.280000000004|
# +--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ***Advance Transformation, checking and removing outliers

# %%
quantiles = order_items.approxQuantile('price',[0.01,0.99],0.0)
low_cutoff,high_cutoff = quantiles[0],quantiles[1]

# %%
low_cutoff,high_cutoff
# Out:
# (9.99, 890.0)

# %%
order_items.select('price').summary().show()
# Out:
# [Stage 112:============================>                            (1 + 1) / 2]
# +-------+------------------+
# |summary|             price|
# +-------+------------------+
# |  count|            112650|
# |   mean|120.65373901471354|
# | stddev|183.63392805026012|
# |    min|              0.85|
# |    25%|              39.9|
# |    50%|             74.99|
# |    75%|             134.9|
# |    max|            6735.0|
# +-------+------------------+

# %%
cleaned_order_items = order_items.filter((col('price') >= low_cutoff) & (col('price') <= high_cutoff))

# %%
cleaned_order_items.show(10)
# Out:
# +--------------------+-------------+--------------------+--------------------+-------------------+------+-------------+
# |            order_id|order_item_id|          product_id|           seller_id|shipping_limit_date| price|freight_value|
# +--------------------+-------------+--------------------+--------------------+-------------------+------+-------------+
# |00010242fe8c5a6d1...|            1|4244733e06e7ecb49...|48436dade18ac8b2b...|2017-09-19 09:45:35|  58.9|        13.29|
# |00018f77f2f0320c5...|            1|e5f2d52b802189ee6...|dd7ddc04e1b6c2c61...|2017-05-03 11:05:13| 239.9|        19.93|
# |000229ec398224ef6...|            1|c777355d18b72b67a...|5b51032eddd242adc...|2018-01-18 14:48:30| 199.0|        17.87|
# |00024acbcdf0a6daa...|            1|7634da152a4610f15...|9d7a1d34a50524090...|2018-08-15 10:10:18| 12.99|        12.79|
# |00042b26cf59d7ce6...|            1|ac6c3623068f30de0...|df560393f3a51e745...|2017-02-13 13:57:51| 199.9|        18.14|
# |00048cc3ae777c65d...|            1|ef92defde845ab845...|6426d21aca402a131...|2017-05-23 03:55:27|  21.9|        12.69|
# |00054e8431b9d7675...|            1|8d4f2bb7e93e6710a...|7040e82f899a04d1b...|2017-12-14 12:10:31|  19.9|        11.85|
# |000576fe39319847c...|            1|557d850972a7d6f79...|5996cddab893a4652...|2018-07-10 12:30:45| 810.0|        70.75|
# |0005a1a1728c9d785...|            1|310ae3c140ff94b03...|a416b6a846a117243...|2018-03-26 18:31:29|145.95|        11.65|
# |0005f50442cb953dc...|            1|4535b0e1091c278df...|ba143b05f0110f0dc...|2018-07-06 14:10:56| 53.99|         11.4|
# +--------------------+-------------+--------------------+--------------------+-------------------+------+-------------+
# only showing top 10 rows

# %%
**Categorizing Values

# %%
cleaned_products = products.withColumn(
    'product_s_cat',
    when(col('product_weight_g') < 250, 'small')
    .when(col('product_weight_g') < 600, 'medium')
    .otherwise('large')
)

# %%
cleaned_products.show()
# Out:
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+-------------+
# |          product_id|product_category_name|product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|product_s_cat|
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+-------------+
# |1e9e8ef04dbcff454...|           perfumaria|                 40|                       287|                 1|           small|               16|               10|              14|        large|
# |3aa071139cb16b67c...|                artes|                 44|                       276|                 1|           large|               30|               18|              20|        large|
# |96bd76ec8810374ed...|        esporte_lazer|                 46|                       250|                 1|           small|               18|                9|              15|        large|
# |cef67bcfe19066a93...|                bebes|                 27|                       261|                 1|           large|               26|                4|              26|        large|
# |9dc1a7de274444849...| utilidades_domest...|                 37|                       402|                 4|           large|               20|               17|              13|        large|
# |41d3672d4792049fa...| instrumentos_musi...|                 60|                       745|                 1|           small|               38|                5|              11|        large|
# |732bd381ad09e530f...|           cool_stuff|                 56|                      1272|                 4|           large|               70|               24|              44|        large|
# |2548af3e6e77a690c...|     moveis_decoracao|                 56|                       184|                 2|           large|               40|                8|              40|        large|
# |37cc742be07708b53...|     eletrodomesticos|                 57|                       163|                 1|           large|               27|               13|              17|        large|
# |8c92109888e8cdf9d...|           brinquedos|                 36|                      1156|                 1|           large|               17|               10|              12|        large|
# |14aa47b7fe5c25522...|      cama_mesa_banho|                 54|                       630|                 1|           large|               16|               10|              16|        large|
# |03b63c5fc16691530...|                bebes|                 49|                       728|                 4|           large|               50|               19|              45|        large|
# |cf55509ea8edaaac1...| instrumentos_musi...|                 43|                      1827|                 3|           large|               17|                7|              17|        large|
# |7bb6f29c2be577161...|     moveis_decoracao|                 51|                      2083|                 2|           large|               68|               11|              13|        large|
# |eb31436580a610f20...| construcao_ferram...|                 59|                      1602|                 4|           small|               17|                7|              17|        large|
# |3bb7f144022e67327...|        esporte_lazer|                 22|                      3021|                 1|           large|               16|                2|              11|        large|
# |6a2fb4dd53d2cdb88...|           perfumaria|                 39|                       346|                 2|           large|               27|                5|              20|        large|
# |a1b71017a84f92fd8...| informatica_acess...|                 59|                       636|                 1|           large|               40|               15|              20|        large|
# |a0736b92e52f6cead...|     moveis_decoracao|                 56|                       296|                 2|           large|              100|                7|              15|        large|
# |f53103a77d9cf245e...|      cama_mesa_banho|                 52|                       206|                 1|           large|               16|               10|              16|        large|
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+-------------+
# only showing top 20 rows

# %% [markdown]
# **Total Revenue per Seller

# %%
detailed_orders.groupBy('seller_id').agg(sum('payment_value').alias('total')).orderBy('total',ascending=False).show()
# Out:
# [Stage 146:============================>                            (2 + 2) / 4]
# +--------------------+------------------+
# |           seller_id|             total|
# +--------------------+------------------+
# |7c67e1448b00f6e96...|         507166.91|
# |1025f0e2d44d7041d...| 308222.0399999999|
# |4a3ca9315b744ce9f...|301245.26999999984|
# |1f50f920176fa81da...| 290253.4199999998|
# |53243585a1d6dc264...|284903.07999999996|
# |da8622b14eb17ae28...| 272219.3200000001|
# |4869f7a5dfa277a7d...| 264166.1199999999|
# |955fee9216a65b617...| 236322.3000000002|
# |fa1c13f2614d7b5c4...|         206513.23|
# |7e93a43ef30c4f03f...|185134.21000000005|
# |6560211a19b47992c...|179657.74999999974|
# |7a67c85e85bb2ce85...|169030.80000000008|
# |                NULL|162591.95000000004|
# |25c5c91f63607446a...|         160534.74|
# |a1043bafd471dff53...|154356.91000000003|
# |46dc3b2cc0980fb8e...|148864.34000000003|
# |b37c4c02bda3161a7...|         145319.04|
# |620c87c171fb2a6dd...|145267.94999999987|
# |cc419e0650a3c5ba7...|141309.57999999978|
# |5dceca129747e92ff...|132974.41999999998|
# +--------------------+------------------+
# only showing top 20 rows

# %%
# !hadoop fs -ls /data/
# Out:
# Found 10 items
# drwxr-xr-x   - root      hadoop          0 2025-12-24 12:44 /data/dataproc
# -rw-r--r--   2 iantrisdc hadoop    9033957 2025-12-23 06:13 /data/olist_customers_dataset.csv
# -rw-r--r--   2 iantrisdc hadoop   61273883 2025-12-23 06:13 /data/olist_geolocation_dataset.csv
# -rw-r--r--   2 iantrisdc hadoop   15438671 2025-12-23 06:13 /data/olist_order_items_dataset.csv
# -rw-r--r--   2 iantrisdc hadoop    5777138 2025-12-23 06:13 /data/olist_order_payments_dataset.csv
# -rw-r--r--   2 iantrisdc hadoop   14451670 2025-12-23 06:13 /data/olist_order_reviews_dataset.csv
# -rw-r--r--   2 iantrisdc hadoop   17654914 2025-12-23 06:13 /data/olist_orders_dataset.csv
# -rw-r--r--   2 iantrisdc hadoop    2379446 2025-12-23 06:13 /data/olist_products_dataset.csv
# -rw-r--r--   2 iantrisdc hadoop     174703 2025-12-23 06:13 /data/olist_sellers_dataset.csv
# -rw-r--r--   2 iantrisdc hadoop       2613 2025-12-23 06:13 /data/product_category_name_translation.csv

# %%
detailed_orders.write.mode('overwrite').parquet('/data/dataproc')
